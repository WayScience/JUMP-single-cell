# %% [markdown]
# # Download and Save Image Metadata

# %%
from pathlib import Path, PurePosixPath

import pandas as pd
import s3fs

# %% [markdown]
# ## Paths and Names

# %%
bucket = "cellpainting-gallery"
run_name = "2020_11_04_CPJUMP1"
prefix = f"cpg0000-jump-pilot/source_4/workspace/load_data_csv/{run_name}"

output_csv = Path(f"image_metadata/{run_name}_all_plates.csv")

s3_glob = f"{bucket}/{prefix}/*/load_data.csv"

# %% [markdown]
# ## Download and Concatenate Metadata

# %%
storage_options = {"anon": True}

fs = s3fs.S3FileSystem(anon=True)
csv_keys = sorted(fs.glob(s3_glob))

if not csv_keys:
    raise FileNotFoundError(f"No files found for pattern: s3://{s3_glob}")

print(f"Found {len(csv_keys)} plate CSV files under {run_name}")

dfs = []
for key in csv_keys:
    s3_url = f"s3://{key}"
    plate = PurePosixPath(key).parts[-2]

    print(f"Reading: {s3_url}")
    df = pd.read_csv(s3_url, storage_options=storage_options)
    df["source_plate"] = plate
    df["source_s3_path"] = s3_url
    dfs.append(df)

merged_df = pd.concat(dfs, axis=0, ignore_index=True)
# Out:
# Found 51 plate CSV files under 2020_11_04_CPJUMP1
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116991/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116992/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116993/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116994/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116995/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116996/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116997/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116998/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00116999/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117000/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117001/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117002/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117003/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117004/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117005/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117006/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117008/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117009/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117010/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117011/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117012/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117013/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117015/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117016/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117017/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117019/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117020/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117021/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117022/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117023/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117024/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117025/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117026/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117050/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117051/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117052/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117053/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117054/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00117055/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118039/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118040/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118041/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118042/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118043/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118044/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118045/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118046/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118047/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118048/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118049/load_data.csv
# Reading: s3://cellpainting-gallery/cpg0000-jump-pilot/source_4/workspace/load_data_csv/2020_11_04_CPJUMP1/BR00118050/load_data.csv

# %% [markdown]
# ## Save Metadata

# %%
output_csv.parent.mkdir(parents=True, exist_ok=True)
merged_df.to_csv(output_csv, index=False)

print(f"Saved merged CSV to: {output_csv}")
print(f"Merged shape: {merged_df.shape}")
# Out:
# Saved merged CSV to: image_metadata/2020_11_04_CPJUMP1_all_plates.csv
# Merged shape: (186925, 36)
