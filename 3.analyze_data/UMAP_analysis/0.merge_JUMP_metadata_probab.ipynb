# %% [markdown]
# # Add necessary metadata to all features model probability file

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import pandas as pd

# %% [markdown]
# ## Load in data frames

# %%
prob_dir = pathlib.Path("../../../Way Science Lab Dropbox/JUMP Processed Data/sc_predicted_probabilities")

prob_df = pd.read_parquet(pathlib.Path(f"{prob_dir}/model_probabilities.parquet"))
metadata_df = pd.read_parquet(pathlib.Path(f"{prob_dir}/model_probabilities_meta_columns.parquet"))

print(metadata_df.shape)
metadata_df.head()
# Out:
# (41919720, 5)
#   Metadata_model_type Metadata_Well Metadata_plate  \
# 0               final           A01     BR00116996
# 1               final           A01     BR00116996
# 2               final           A01     BR00116996
# 3               final           A01     BR00116996
# 4               final           A01     BR00116996
#
#    Metadata_ObjectNumber_cytoplasm  Metadata_Site
# 0                                1              1
# 1                                2              1
# 2                                3              1
# 3                                4              1
# 4                                5              1

# %% [markdown]
# ## Concat probability and necessary metadata

# %%
concatenated_prob_df = pd.concat([prob_df, metadata_df[["Metadata_ObjectNumber_cytoplasm", "Metadata_Site"]]], axis=1)

concatenated_prob_df.rename(columns={"Metadata_plate": "Metadata_Plate"}, inplace=True)

concatenated_prob_df.to_parquet("./data/all_features_probabilities.parquet")

print(concatenated_prob_df.shape)
concatenated_prob_df.head()
# Out:
# (41919720, 20)
#       ADCCM  Anaphase  Apoptosis     Binuclear  Elongated     Grape  \
# 0  0.051008  0.211197   0.115538  7.683850e-03   0.059707  0.043649
# 1  0.008728  0.038776   0.003018  2.421637e-03   0.406965  0.036579
# 2  0.002404  0.000009   0.000051  2.444155e-03   0.000181  0.000599
# 3  0.002428  0.001167   0.989989  2.610488e-11   0.000184  0.004180
# 4  0.010993  0.047032   0.817058  2.187876e-05   0.012261  0.059017
#
#            Hole    Interphase     Large  Metaphase  MetaphaseAlignment  \
# 0  4.759277e-02  1.033536e-02  0.036752   0.099821            0.023167
# 1  1.043440e-02  6.927929e-03  0.005184   0.366973            0.002281
# 2  2.589783e-04  1.062534e-03  0.003286   0.000299            0.002351
# 3  2.228079e-07  1.643755e-17  0.000015   0.001357            0.000678
# 4  1.614873e-03  5.193100e-08  0.000553   0.042322            0.005592
#
#      OutOfFocus     Polylobed  Prometaphase  SmallIrregular  \
# 0  2.601537e-01  2.784537e-03  2.658478e-03    2.795364e-02
# 1  1.068267e-01  1.086595e-03  9.656659e-04    2.832116e-03
# 2  9.720542e-01  1.353909e-02  1.529966e-05    1.444214e-03
# 3  3.249089e-07  9.469420e-09  2.895316e-07    5.325868e-09
# 4  2.286300e-03  8.843109e-06  7.789092e-04    4.601835e-04
#
#   Metadata_model_type Metadata_Well Metadata_Plate  \
# 0               final           A01     BR00116996
# 1               final           A01     BR00116996
# 2               final           A01     BR00116996
# 3               final           A01     BR00116996
# 4               final           A01     BR00116996
#
#    Metadata_ObjectNumber_cytoplasm  Metadata_Site
# 0                                1              1
# 1                                2              1
# 2                                3              1
# 3                                4              1
# 4                                5              1
